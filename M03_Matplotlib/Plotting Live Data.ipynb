# %%
from matplotlib.animation import FuncAnimation
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')


def animate(i):
    data = pd.read_csv('..\\Datasets\\data.csv')
    x = data['x_value']
    y1 = data['total_1']
    y2 = data['total_2']

    plt.cla()

    line1, = plt.plot(x, y1, label='Chan1')
    line2, = plt.plot(x, y2, label='Chan2')
    plt.legend()
    return line1, line2


ani = FuncAnimation(
    fig=plt.gcf(),
    func=animate,
    interval=1000,
    blit=True
)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_5340\1672219879.py:21: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(

# %%
data = pd.read_csv('..\\Datasets\\data.csv')
data
# Out:
#     x_value  total_1  total_2
# 0         0     1000     1000
# 1         1      996      997
# 2         2     1003     1003
# 3         3     1004     1002
# 4         4     1009     1002
# 5         5     1010     1001
# 6         6     1004     1000
# 7         7     1007      995
# 8         8     1015      996
# 9         9     1020      996
# 10       10     1018     1001
# 11       11     1013     1005
# 12       12     1017     1004
# 13       13     1016      999
# 14       14     1013      994
# 15       15     1018      991
