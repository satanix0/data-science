# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  2.545511 -0.154628  2.585393 -3.693370  0.661193       1
# 1 -4.188078 -0.047810 -1.652695 -1.292587  3.377861       0
# 2  0.195439  1.916279  0.466273  2.105466  1.094965       1
# 3 -2.448349 -3.218311  0.015937 -0.563056  0.252594       0
# 4 -2.266363 -1.043354  0.601856 -2.064471  0.189932       0

# %%
bag = BaggingClassifier(max_features = 2)
bag.fit(df.iloc[:, :5], df.iloc[:, -1])

bag.estimators_
# Out:
# [DecisionTreeClassifier(random_state=264365385),
#  DecisionTreeClassifier(random_state=107318844),
#  DecisionTreeClassifier(random_state=815084260),
#  DecisionTreeClassifier(random_state=1794125817),
#  DecisionTreeClassifier(random_state=1070962384),
#  DecisionTreeClassifier(random_state=1773556478),
#  DecisionTreeClassifier(random_state=719716134),
#  DecisionTreeClassifier(random_state=449284495),
#  DecisionTreeClassifier(random_state=911596379),
#  DecisionTreeClassifier(random_state=1366569059)]

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features = 2)
rf.fit(df.iloc[:,:5], df.iloc[:,-1])
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features=2, random_state=271674754),
#  DecisionTreeClassifier(max_features=2, random_state=1623081337),
#  DecisionTreeClassifier(max_features=2, random_state=613268952),
#  DecisionTreeClassifier(max_features=2, random_state=649061047),
#  DecisionTreeClassifier(max_features=2, random_state=375359689),
#  DecisionTreeClassifier(max_features=2, random_state=1787785462),
#  DecisionTreeClassifier(max_features=2, random_state=1231977269),
#  DecisionTreeClassifier(max_features=2, random_state=1743628297),
#  DecisionTreeClassifier(max_features=2, random_state=2123814877),
#  DecisionTreeClassifier(max_features=2, random_state=1766781619),
#  DecisionTreeClassifier(max_features=2, random_state=814963683),
#  DecisionTreeClassifier(max_features=2, random_state=1246497971),
#  DecisionTreeClassifier(max_features=2, random_state=215807822),
#  DecisionTreeClassifier(max_features=2, random_state=444119534),
#  DecisionTreeClassifier(max_features=2, random_state=135435765),
#  DecisionTreeClassifier(max_features=2, random_state=340713207),
#  DecisionTreeClassifier(max_features=2, random_state=76367052),
#  DecisionTreeClassifier(max_features=2, random_state=2114409087),
#  DecisionTreeClassifier(max_features=2, random_state=1438515411),
#  DecisionTreeClassifier(max_features=2, random_state=800124993),
#  DecisionTreeClassifier(max_features=2, random_state=1296971324),
#  DecisionTreeClassifier(max_features=2, random_state=1305030699),
#  DecisionTreeClassifier(max_features=2, random_state=169263352),
#  DecisionTreeClassifier(max_features=2, random_state=1101338314),
#  DecisionTreeClassifier(max_features=2, random_state=688775210),
#  DecisionTreeClassifier(max_features=2, random_state=849728254),
#  DecisionTreeClassifier(max_features=2, random_state=368161298),
#  DecisionTreeClassifier(max_features=2, random_state=1782325280),
#  DecisionTreeClassifier(max_features=2, random_state=296222082),
#  DecisionTreeClassifier(max_features=2, random_state=1451561409),
#  DecisionTreeClassifier(max_features=2, random_state=1952379659),
#  DecisionTreeClassifier(max_features=2, random_state=1677998751),
#  DecisionTreeClassifier(max_features=2, random_state=438502361),
#  DecisionTreeClassifier(max_features=2, random_state=635209007),
#  DecisionTreeClassifier(max_features=2, random_state=1967584893),
#  DecisionTreeClassifier(max_features=2, random_state=818097146),
#  DecisionTreeClassifier(max_features=2, random_state=455729977),
#  DecisionTreeClassifier(max_features=2, random_state=457540029),
#  DecisionTreeClassifier(max_features=2, random_state=1227310957),
#  DecisionTreeClassifier(max_features=2, random_state=1921084819),
#  DecisionTreeClassifier(max_features=2, random_state=1495525285),
#  DecisionTreeClassifier(max_features=2, random_state=1291022932),
#  DecisionTreeClassifier(max_features=2, random_state=1373455144),
#  DecisionTreeClassifier(max_features=2, random_state=1642934264),
#  DecisionTreeClassifier(max_features=2, random_state=695257082),
#  DecisionTreeClassifier(max_features=2, random_state=777046191),
#  DecisionTreeClassifier(max_features=2, random_state=1744737752),
#  DecisionTreeClassifier(max_features=2, random_state=1109673212),
#  DecisionTreeClassifier(max_features=2, random_state=1906786368),
#  DecisionTreeClassifier(max_features=2, random_state=1271329318),
#  DecisionTreeClassifier(max_features=2, random_state=724599620),
#  DecisionTreeClassifier(max_features=2, random_state=1788072013),
#  DecisionTreeClassifier(max_features=2, random_state=57266161),
#  DecisionTreeClassifier(max_features=2, random_state=998784014),
#  DecisionTreeClassifier(max_features=2, random_state=1328811741),
#  DecisionTreeClassifier(max_features=2, random_state=381595109),
#  DecisionTreeClassifier(max_features=2, random_state=1029343278),
#  DecisionTreeClassifier(max_features=2, random_state=2129704362),
#  DecisionTreeClassifier(max_features=2, random_state=1387968823),
#  DecisionTreeClassifier(max_features=2, random_state=1714656617),
#  DecisionTreeClassifier(max_features=2, random_state=822903426),
#  DecisionTreeClassifier(max_features=2, random_state=930030807),
#  DecisionTreeClassifier(max_features=2, random_state=1413128146),
#  DecisionTreeClassifier(max_features=2, random_state=124278461),
#  DecisionTreeClassifier(max_features=2, random_state=190585725),
#  DecisionTreeClassifier(max_features=2, random_state=648172948),
#  DecisionTreeClassifier(max_features=2, random_state=880511545),
#  DecisionTreeClassifier(max_features=2, random_state=2007872352),
#  DecisionTreeClassifier(max_features=2, random_state=946659351),
#  DecisionTreeClassifier(max_features=2, random_state=705389484),
#  DecisionTreeClassifier(max_features=2, random_state=1508281486),
#  DecisionTreeClassifier(max_features=2, random_state=1361533234),
#  DecisionTreeClassifier(max_features=2, random_state=350624339),
#  DecisionTreeClassifier(max_features=2, random_state=456915257),
#  DecisionTreeClassifier(max_features=2, random_state=762538855),
#  DecisionTreeClassifier(max_features=2, random_state=58924735),
#  DecisionTreeClassifier(max_features=2, random_state=789847508),
#  DecisionTreeClassifier(max_features=2, random_state=1644636662),
#  DecisionTreeClassifier(max_features=2, random_state=1221328414),
#  DecisionTreeClassifier(max_features=2, random_state=61311704),
#  DecisionTreeClassifier(max_features=2, random_state=1986460150),
#  DecisionTreeClassifier(max_features=2, random_state=1466421505),
#  DecisionTreeClassifier(max_features=2, random_state=1364309254),
#  DecisionTreeClassifier(max_features=2, random_state=715696263),
#  DecisionTreeClassifier(max_features=2, random_state=35571958),
#  DecisionTreeClassifier(max_features=2, random_state=1272821393),
#  DecisionTreeClassifier(max_features=2, random_state=1583935833),
#  DecisionTreeClassifier(max_features=2, random_state=369869658),
#  DecisionTreeClassifier(max_features=2, random_state=1485223537),
#  DecisionTreeClassifier(max_features=2, random_state=1454361777),
#  DecisionTreeClassifier(max_features=2, random_state=336491840),
#  DecisionTreeClassifier(max_features=2, random_state=619559017),
#  DecisionTreeClassifier(max_features=2, random_state=1443844728),
#  DecisionTreeClassifier(max_features=2, random_state=1008552338),
#  DecisionTreeClassifier(max_features=2, random_state=1853900126),
#  DecisionTreeClassifier(max_features=2, random_state=1252583667),
#  DecisionTreeClassifier(max_features=2, random_state=2134679736),
#  DecisionTreeClassifier(max_features=2, random_state=581365373),
#  DecisionTreeClassifier(max_features=2, random_state=1307325847),
#  DecisionTreeClassifier(max_features=2, random_state=1541484387)]

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
