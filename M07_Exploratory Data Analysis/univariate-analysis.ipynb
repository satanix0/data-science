# %% [markdown]
# ### The primary goal of univariate analysis is to summarize and understand the data for a single variable. It involves performing various statistical techniques and visualizations to explore and describe the data.

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 273          274         0       1
# 420          421         0       3
# 371          372         0       3
# 245          246         0       1
# 556          557         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 273                              Natsch, Mr. Charles H    male  37.0      0
# 420                             Gheorgheff, Mr. Stanio    male   NaN      0
# 371                          Wiklund, Mr. Jakob Alfred    male  18.0      1
# 245                        Minahan, Dr. William Edward    male  44.0      2
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
#
#      Parch    Ticket     Fare Cabin Embarked
# 273      1  PC 17596  29.7000  C118        C
# 420      0    349254   7.8958   NaN        C
# 371      0   3101267   6.4958   NaN        S
# 245      0     19928  90.0000   C78        Q
# 556      0     11755  39.6000   A16        C

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <body>
#
# <h4>Cols in dataset are of mainly 2 types</h4>
#
# <ul>
#   <li>Categorical</li>
#   <li>Numerical</li>
# </ul>
# </body>
# </html>

# %% [markdown]
# ### 1. Categorical Data

# %% [markdown]
# #### a. Countplot

# %%
sns.countplot(data = df, x = 'Embarked',hue='Pclass')
#df['Survived'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: >

# %% [markdown]
# #### b. Pie Chart

# %%
df['Survived'].value_counts().plot(kind= 'pie',autopct= '%.2f')
# Out:
# <Axes: ylabel='Survived'>

# %% [markdown]
# ### 2. Numerical Data

# %% [markdown]
# ### a. Histogram

# %%
sns.histplot(data = df,x= 'Age',bins = 10,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ### b. displot

# %%
sns.displot(data = df,x= 'Age',kde= True,color= 'red')

# %% [markdown]
# ### c. boxplot

# %%
sns.boxplot(data = df,x = 'Age' )
# Out:
# <Axes: xlabel='Age'>
