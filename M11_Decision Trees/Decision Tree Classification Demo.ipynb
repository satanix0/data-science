# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
X=iris.data
X[10]
# Out:
# array([5.4, 3.7, 1.5, 0.2])

# %%
y=iris.target
y[10]
# 3 Classes
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333

# %%
from sklearn.tree import plot_tree

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 80,50

plot_tree(clf)
# Out:
# [Text(0.4, 0.9, 'x[3] <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [39, 40, 41]'),
#  Text(0.3, 0.7, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.5, 0.7, 'x[3] <= 1.65\ngini = 0.5\nsamples = 81\nvalue = [0, 40, 41]'),
#  Text(0.45, 0.8, '  False'),
#  Text(0.2, 0.5, 'x[2] <= 4.95\ngini = 0.093\nsamples = 41\nvalue = [0, 39, 2]'),
#  Text(0.1, 0.3, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(0.3, 0.3, 'x[3] <= 1.55\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.2, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'x[2] <= 4.85\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(0.7, 0.3, 'x[1] <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9, 0.3, 'gini = 0.0\nsamples = 36\nvalue = [0, 0, 36]')]

# %%
clf.predict([[3, 5, 4,2]])
# Out:
# array([1])

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
data.Gender.value_counts()
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
data.replace({'Male':0,'Female':1}, inplace = True)
data.head()
# Out:
# C:\Users\piyus\AppData\Local\Temp\ipykernel_21840\1798856808.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({'Male':0,'Female':1}, inplace = True)
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       0   19            19000          0
# 1  15810944       0   35            20000          0
# 2  15668575       1   26            43000          0
# 3  15603246       1   27            57000          0
# 4  15804002       0   19            76000          0

# %%
X=data.iloc[:, 1:4].values
y=data.iloc[:,-1].values

# %%
X.shape
# Out:
# (400, 3)

# %%
y.shape
# Out:
# (400,)

# %%
clf1=DecisionTreeClassifier(max_depth=3, criterion='entropy')

# %%
clf1.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
rcParams['figure.figsize'] = 80,50

plot_tree(clf1)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 42.5\nentropy = 0.941\nsamples = 400\nvalue = [257, 143]'),
#  Text(0.25, 0.625, 'x[2] <= 90500.0\nentropy = 0.638\nsamples = 285\nvalue = [239.0, 46.0]'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'x[1] <= 36.5\nentropy = 0.23\nsamples = 241\nvalue = [232, 9]'),
#  Text(0.0625, 0.125, 'entropy = 0.0\nsamples = 162\nvalue = [162, 0]'),
#  Text(0.1875, 0.125, 'entropy = 0.512\nsamples = 79\nvalue = [70, 9]'),
#  Text(0.375, 0.375, 'x[2] <= 119000.0\nentropy = 0.632\nsamples = 44\nvalue = [7, 37]'),
#  Text(0.3125, 0.125, 'entropy = 0.871\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.4375, 0.125, 'entropy = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.75, 0.625, 'x[2] <= 38500.0\nentropy = 0.626\nsamples = 115\nvalue = [18, 97]'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[2] <= 22500.0\nentropy = 0.191\nsamples = 34\nvalue = [1, 33]'),
#  Text(0.5625, 0.125, 'entropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.6875, 0.125, 'entropy = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.875, 0.375, 'x[1] <= 52.5\nentropy = 0.741\nsamples = 81\nvalue = [17, 64]'),
#  Text(0.8125, 0.125, 'entropy = 0.889\nsamples = 49\nvalue = [15, 34]'),
#  Text(0.9375, 0.125, 'entropy = 0.337\nsamples = 32\nvalue = [2, 30]')]
