# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = sns.load_dataset('penguins')

# %%
x = np.arange(1,11)
y= np.sin(x)

# %%
plt.plot(x,y,)

# %%
sns.lineplot(x="x",y="y",data=dfc)


plt.show()

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data=df,hue='species',markers=['o','v','+'])
plt.show()

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df = pd.read_csv('C:\\Users\\piyus\\Downloads\\sales.csv')

# %%
df.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...  Province   Region  \
# 0      0.04     Regular Air -213.25       38.94  ...   Nunavut  Nunavut
# 1      0.07  Delivery Truck  457.81      208.16  ...   Nunavut  Nunavut
#
#   Customer Segment Product Category    Product Sub-Category  \
# 0   Small Business  Office Supplies  Storage & Organization
# 1         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin   Ship Date  year
# 0                0.80  10/20/2010  2010
# 1                0.58   10/2/2012  2012
#
# ...

# %%
sns.lineplot(x='year',y='Sales',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Sales'>

# %%
sns.relplot(x='year',y='Sales',data=df,
            ci=None,
            hue='Product Category',
            style='Ship Mode',
            kind='line',
            col='Product Container',
            col_wrap=4
            )

# %%
plt.figure(figsize=(7,4))
sns.lineplot(x='year',y='Profit',data=df,
             ci=None,
             hue='Product Category',
             style='Product Category'
                
)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Profit'>
