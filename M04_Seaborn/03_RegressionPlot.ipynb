# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
diamonds= sns.load_dataset('diamonds')

# %%
diamonds = diamonds.sample(n=200) # taking sample of 200
diamonds.head()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 25013   2.04       Good     J     VS2   59.6   56.0  13550  8.26  8.31  4.94
# 46223   0.50    Premium     D     VS2   61.4   59.0   1752  5.11  5.15  3.15
# 14232   1.07  Very Good     D     SI1   61.8   61.0   5767  6.54  6.57  4.05
# 48460   0.50       Good     G      IF   64.0   55.0   1976  5.05  5.08  3.24
# 8105    1.15    Premium     I     SI2   62.6   57.0   4347  6.73  6.69  4.20

# %%
sns.regplot(data=diamonds,x='carat',y='price',)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.regplot(data=diamonds,x='carat',y='price',
            fit_reg=False,          
           )
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
plt.xlim((0,2.6))
sns.regplot(data=diamonds,x='carat',y='price',
            scatter=False
           )
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
cut_map={
    "Fair":1,
    "Good":2,
    "Very Good":3,
    "Premium":4,
    "Ideal":4,
}
diamonds['cut_value']=diamonds['cut'].map(arg=cut_map)

diamonds['cut_value'].value_counts()
# Out:
# cut_value
# 4    120
# 3     49
# 2     22
# 1      9
# Name: count, dtype: int64

# %%
sns.regplot(data=diamonds,x='cut_value',y='price',
           
           )
# Out:
# <Axes: xlabel='cut_value', ylabel='price'>

# %%
sns.regplot(data=diamonds,x='cut_value',y='price',
            x_jitter=0.1
           )
# Out:
# <Axes: xlabel='cut_value', ylabel='price'>

# %%
sns.regplot(data=diamonds,x='cut_value',y='price',
            x_estimator=np.mean,
           )
# Out:
# <Axes: xlabel='cut_value', ylabel='price'>
