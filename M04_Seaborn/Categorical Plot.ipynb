# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\piyus\\Downloads\\Udemy Notebooks\\05-Seaborn\\dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.countplot(
    data=df,
    x='division',
)
# Out:
# <AxesSubplot:xlabel='division', ylabel='count'>

# %%
df['level of education'].value_counts(ascending=True).index
# Out:
# Index(['master's degree', 'bachelor's degree', 'high school', 'some college',
#        'associate's degree'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6),dpi=100)

# More Parameters
sns.countplot(
    data=df,
    x='division',
    order=['computer software','printers','office supplies','computer hardware','peripherals'],
    hue='level of education',
    hue_order=df['level of education'].value_counts(ascending=True).index,
    palette='cubehelix'
)

plt.legend(bbox_to_anchor=(1.01,0.5))

# %% [markdown]
# ## Bar Plot

# %%
plt.figure(figsize=(11,6),dpi=200)
sns.barplot(data=df, x = 'level of education',y='salary',
            hue='division',
            estimator=np.mean,
            ci='sd',
            order=["master's degree",'some college',
       "bachelor's degree", "associate's degree", 'high school']
           )
plt.legend(bbox_to_anchor=(1.01,0.58))
plt.tight_layout()

# %%
ddf['level of education'].unique()
# Out:
# array(['some college', "associate's degree", 'high school',
#        "bachelor's degree", "master's degree"], dtype=object)

# %%
penguins= sns.load_dataset('penguins')

# %%
penguins.groupby(by='species').count()['body_mass_g']
# Out:
# species
# Adelie       146
# Chinstrap     68
# Gentoo       119
# Name: body_mass_g, dtype: int64

# %%
# Same data can be visualised as 
sns.set(style='darkgrid')
sns.barplot(x='species',y='body_mass_g',data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>
